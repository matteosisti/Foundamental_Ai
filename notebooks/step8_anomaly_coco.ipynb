# %% [markdown]
# # Step 8 — EoMT COCO Anomaly Segmentation
#
# Evaluates the COCO-trained EoMT Base checkpoint on all 5 anomaly segmentation datasets:
# - RoadAnomaly21 (RA21) — 10 images
# - RoadObstacle21 (RO21) — 30 images
# - LostAndFound (LAF) — 99 images
# - Fishyscapes Static (fs_static) — 20 images
# - Road Anomaly (RA) — 60 images
#
# Post-hoc methods: MSP, MaxEntropy, MaxLogit, RbA
#
# Results are saved to `artifacts/<dataset>_coco/EoMT/` and collected into `results/all_results.json`.

# %% [markdown]
# ## 0. Setup

# %%
from google.colab import drive, userdata
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import subprocess, sys, os

GITHUB_USERNAME = userdata.get('GITHUB_USERNAME')
GITHUB_TOKEN    = userdata.get('GITHUB_TOKEN')
GITHUB_REPO     = userdata.get('GITHUB_REPO')

repo_url = f'https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO}.git'
subprocess.run(['git', 'clone', repo_url, '/content/project'], check=True)

# %cd /content/project
sys.path.insert(0, '/content/project')

print('Setup complete')
# Out:
# /content/project
# Setup complete

# %% [markdown]
# ## 1. Configuration

# %%
# ── Paths ─────────────────────────────────────────────────────
DRIVE_ROOT = '/content/drive/MyDrive/anom_project'
CKPT_DIR   = f'{DRIVE_ROOT}/ckpts/eomt'
DATA_DIR   = f'{DRIVE_ROOT}/Validation_Dataset'
ART        = f'{DRIVE_ROOT}/artifacts'
RESULTS_DIR = f'{DRIVE_ROOT}/results'

# ── Checkpoints ───────────────────────────────────────────────
CKPT_EOMT_COCO = f'{CKPT_DIR}/eomt_coco.bin'
CFG_EOMT_COCO  = 'eomt/configs/dinov2/cityscapes/semantic/eomt_base_640.yaml'
NUM_CLASSES_COCO = 133

# ── Eval settings ─────────────────────────────────────────────
MODE = 'robust'
T    = '1.0'
SEED = '0'

os.makedirs(ART, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)

print('Configuration ready')
print(f'  CKPT COCO:  {CKPT_EOMT_COCO}')
print(f'  MODE: {MODE} | T: {T} | SEED: {SEED}')
print(f'  num_classes: {NUM_CLASSES_COCO}')
# Out:
# Configuration ready
#   CKPT COCO:  /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin
#   MODE: robust | T: 1.0 | SEED: 0
#   num_classes: 133

# %% [markdown]
# ## 2. Runner helpers

# %%
def run(args: list) -> None:
    process = subprocess.Popen(
        args,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
    )
    for line in process.stdout:
        print(line, end='', flush=True)
    process.wait()
    if process.returncode != 0:
        raise subprocess.CalledProcessError(process.returncode, args)


def eomt_coco(data: str, inp: str, method: str) -> None:
    """Run EoMT COCO checkpoint on anomaly dataset + temperature sweep."""
    run([
        'python3', '-m', 'src.runners.run_eomt_eval',
        '--input',        inp,
        '--ckpt',         CKPT_EOMT_COCO,
        '--config',       CFG_EOMT_COCO,
        '--dataset-name', f'{data}_coco',
        '--method',       method,
        '--temperature',  T,
        '--mode',         MODE,
        '--seed',         SEED,
        '--deterministic',
        '--num-classes',  str(NUM_CLASSES_COCO),
        '--artifacts-dir', ART,
        '--save-logits',
    ])
    run([
        'python3', '-m', 'src.runners.sweep_temp_from_cache_eomt',
        '--dataset-name',  f'{data}_coco',
        '--artifacts-dir', ART,
        '--use-latest',
        '--method',        method,
        '--mode',          MODE,
    ])


print('Runner helpers ready')
# Out:
# Runner helpers ready

# %% [markdown]
# ## 3. Sanity check — single image forward pass

# %%
# Verify checkpoint loads correctly before running full evaluation
run([
    'python3', '-m', 'src.runners.run_eomt_eval',
    '--input',        f'{DATA_DIR}/RoadAnomaly21/images/0.png',
    '--ckpt',         CKPT_EOMT_COCO,
    '--config',       CFG_EOMT_COCO,
    '--dataset-name', 'sanity_check_coco',
    '--method',       'msp',
    '--temperature',  T,
    '--mode',         MODE,
    '--seed',         SEED,
    '--deterministic',
    '--num-classes',  str(NUM_CLASSES_COCO),
    '--artifacts-dir', '/tmp/sanity',
])
print('Sanity check passed — checkpoint loads correctly')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [device] cuda
# [ARTIFACTS] /tmp/sanity/sanity_check_coco/EoMT/2026-05-08_15-28-06__msp__T1.0__robust__1a6d6e86
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=sanity_check_coco | method=msp | T=1.0 | mode=robust | sw=False
# AUPRC: 1.3809
# FPR@95TPR: 90.4729
# Images used: 1
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /tmp/sanity/sanity_check_coco/EoMT/2026-05-08_15-28-06__msp__T1.0__robust__1a6d6e86/results/metrics.json
# [SAVED] /tmp/sanity/sanity_check_coco/EoMT/2026-05-08_15-28-06__msp__T1.0__robust__1a6d6e86/results/metrics.csv
# Sanity check passed — checkpoint loads correctly

# %% [markdown]
# ## 4. Evaluation — RoadAnomaly21

# %%
DATA = 'RA21'
INP  = f'{DATA_DIR}/RoadAnomaly21/images/*.*'

for method in ['msp', 'maxentropy', 'maxlogit', 'rba']:
    eomt_coco(DATA, INP, method)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=RA21_coco | method=msp | T=1.0 | mode=robust | sw=False
# AUPRC: 30.7187
# FPR@95TPR: 91.2647
# Images used: 10
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/logits/RA21_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/logits/RA21_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/logits/RA21_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/logits/RA21_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a
# [T=0.5] AUPRC=15.1537 | FPR95=95.1658 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/sweep/msp__robust/T0.5__metrics.json
# [T=0.75] AUPRC=14.8718 | FPR95=93.8376 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/sweep/msp__robust/T0.75__metrics.json
# [T=1.0] AUPRC=15.1769 | FPR95=92.9750 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/sweep/msp__robust/T1.0__metrics.json
# [T=1.1] AUPRC=15.5121 | FPR95=92.6205 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/sweep/msp__robust/T1.1__metrics.json
# [T=1.25] AUPRC=16.1439 | FPR95=90.9092 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/sweep/msp__robust/T1.25__metrics.json
# [T=1.5] AUPRC=17.5654 | FPR95=85.2186 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/sweep/msp__robust/T1.5__metrics.json
# [T=2.0] AUPRC=22.1741 | FPR95=83.1520 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/sweep/msp__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-28-43__msp__T1.0__robust__e28b287a/sweep/msp__robust
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=RA21_coco | method=maxentropy | T=1.0 | mode=robust | sw=False
# AUPRC: 38.9409
# FPR@95TPR: 87.0457
# Images used: 10
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/logits/RA21_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/logits/RA21_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/logits/RA21_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/logits/RA21_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7
# [T=0.5] AUPRC=15.3665 | FPR95=95.1152 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/sweep/maxentropy__robust/T0.5__metrics.json
# [T=0.75] AUPRC=14.6114 | FPR95=93.7684 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/sweep/maxentropy__robust/T0.75__metrics.json
# [T=1.0] AUPRC=15.9579 | FPR95=92.7283 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/sweep/maxentropy__robust/T1.0__metrics.json
# [T=1.1] AUPRC=17.4620 | FPR95=91.6267 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/sweep/maxentropy__robust/T1.1__metrics.json
# [T=1.25] AUPRC=20.1097 | FPR95=87.4673 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/sweep/maxentropy__robust/T1.25__metrics.json
# [T=1.5] AUPRC=25.3602 | FPR95=79.9275 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/sweep/maxentropy__robust/T1.5__metrics.json
# [T=2.0] AUPRC=35.8052 | FPR95=80.2571 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/sweep/maxentropy__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-29-32__maxentropy__T1.0__robust__145999b7/sweep/maxentropy__robust
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=RA21_coco | method=maxlogit | T=1.0 | mode=robust | sw=False
# AUPRC: 16.8416
# FPR@95TPR: 63.9901
# Images used: 10
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/logits/RA21_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/logits/RA21_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/logits/RA21_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/logits/RA21_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de
# [T=0.5] AUPRC=16.1682 | FPR95=66.5559 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/sweep/maxlogit__robust/T0.5__metrics.json
# [T=0.75] AUPRC=16.1682 | FPR95=66.5559 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/sweep/maxlogit__robust/T0.75__metrics.json
# [T=1.0] AUPRC=16.1682 | FPR95=66.5559 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/sweep/maxlogit__robust/T1.0__metrics.json
# [T=1.1] AUPRC=16.1682 | FPR95=66.5559 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/sweep/maxlogit__robust/T1.1__metrics.json
# [T=1.25] AUPRC=16.1682 | FPR95=66.5559 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/sweep/maxlogit__robust/T1.25__metrics.json
# [T=1.5] AUPRC=16.1682 | FPR95=66.5559 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/sweep/maxlogit__robust/T1.5__metrics.json
# [T=2.0] AUPRC=16.1682 | FPR95=66.5559 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/sweep/maxlogit__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-04__maxlogit__T1.0__robust__7f31b0de/sweep/maxlogit__robust
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=RA21_coco | method=rba | T=1.0 | mode=robust | sw=False
# AUPRC: 16.4201
# FPR@95TPR: 68.1622
# Images used: 10
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/logits/RA21_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/logits/RA21_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/logits/RA21_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/logits/RA21_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367
# [T=0.5] AUPRC=15.5455 | FPR95=66.8434 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/sweep/rba__robust/T0.5__metrics.json
# [T=0.75] AUPRC=15.5265 | FPR95=67.1845 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/sweep/rba__robust/T0.75__metrics.json
# [T=1.0] AUPRC=15.5014 | FPR95=67.5546 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/sweep/rba__robust/T1.0__metrics.json
# [T=1.1] AUPRC=15.5060 | FPR95=67.6960 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/sweep/rba__robust/T1.1__metrics.json
# [T=1.25] AUPRC=15.5278 | FPR95=67.8465 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/sweep/rba__robust/T1.25__metrics.json
# [T=1.5] AUPRC=15.6169 | FPR95=67.3268 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/sweep/rba__robust/T1.5__metrics.json
# [T=2.0] AUPRC=15.8532 | FPR95=65.2537 | saved /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/sweep/rba__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/RA21_coco/EoMT/2026-05-08_15-30-35__rba__T1.0__robust__bbe56367/sweep/rba__robust

# %% [markdown]
# ## 5. Evaluation — RoadObstacle21

# %%
DATA = 'RO21'
INP  = f'{DATA_DIR}/RoadObstacle21/images/*.*'

for method in ['msp', 'maxentropy', 'maxlogit', 'rba']:
    eomt_coco(DATA, INP, method)
# Out:
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=RO21_coco | method=msp | T=1.0 | mode=robust | sw=False
# AUPRC: 0.5653
# FPR@95TPR: 94.0795
# Images used: 30
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/logits/RO21_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/logits/RO21_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/logits/RO21_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/logits/RO21_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b
# [T=0.5] AUPRC=0.8937 | FPR95=55.5472 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/sweep/msp__robust/T0.5__metrics.json
# [T=0.75] AUPRC=0.8126 | FPR95=74.9421 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/sweep/msp__robust/T0.75__metrics.json
# [T=1.0] AUPRC=0.7258 | FPR95=80.8732 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/sweep/msp__robust/T1.0__metrics.json
# [T=1.1] AUPRC=0.7012 | FPR95=86.8139 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/sweep/msp__robust/T1.1__metrics.json
# [T=1.25] AUPRC=0.6694 | FPR95=88.1000 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/sweep/msp__robust/T1.25__metrics.json
# [T=1.5] AUPRC=0.6450 | FPR95=87.9363 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/sweep/msp__robust/T1.5__metrics.json
# [T=2.0] AUPRC=0.6666 | FPR95=79.9190 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/sweep/msp__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-31-06__msp__T1.0__robust__0de7411b/sweep/msp__robust
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=RO21_coco | method=maxentropy | T=1.0 | mode=robust | sw=False
# AUPRC: 1.7086
# FPR@95TPR: 88.4958
# Images used: 30
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/logits/RO21_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/logits/RO21_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/logits/RO21_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/logits/RO21_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0
# [T=0.5] AUPRC=1.0693 | FPR95=54.3504 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/sweep/maxentropy__robust/T0.5__metrics.json
# [T=0.75] AUPRC=1.0218 | FPR95=72.2691 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/sweep/maxentropy__robust/T0.75__metrics.json
# [T=1.0] AUPRC=0.9208 | FPR95=74.0481 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/sweep/maxentropy__robust/T1.0__metrics.json
# [T=1.1] AUPRC=0.8642 | FPR95=75.8194 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/sweep/maxentropy__robust/T1.1__metrics.json
# [T=1.25] AUPRC=0.8500 | FPR95=75.8317 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/sweep/maxentropy__robust/T1.25__metrics.json
# [T=1.5] AUPRC=0.8737 | FPR95=73.0488 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/sweep/maxentropy__robust/T1.5__metrics.json
# [T=2.0] AUPRC=0.9906 | FPR95=57.4040 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/sweep/maxentropy__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-32-39__maxentropy__T1.0__robust__93b24af0/sweep/maxentropy__robust
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=RO21_coco | method=maxlogit | T=1.0 | mode=robust | sw=False
# AUPRC: 0.3799
# FPR@95TPR: 99.9986
# Images used: 30
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/logits/RO21_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/logits/RO21_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/logits/RO21_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/logits/RO21_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13
# [T=0.5] AUPRC=0.3752 | FPR95=99.9992 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/sweep/maxlogit__robust/T0.5__metrics.json
# [T=0.75] AUPRC=0.3752 | FPR95=99.9992 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/sweep/maxlogit__robust/T0.75__metrics.json
# [T=1.0] AUPRC=0.3752 | FPR95=99.9992 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/sweep/maxlogit__robust/T1.0__metrics.json
# [T=1.1] AUPRC=0.3752 | FPR95=99.9992 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/sweep/maxlogit__robust/T1.1__metrics.json
# [T=1.25] AUPRC=0.3752 | FPR95=99.9992 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/sweep/maxlogit__robust/T1.25__metrics.json
# [T=1.5] AUPRC=0.3752 | FPR95=99.9992 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/sweep/maxlogit__robust/T1.5__metrics.json
# [T=2.0] AUPRC=0.3752 | FPR95=99.9992 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/sweep/maxlogit__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-17__maxlogit__T1.0__robust__37038a13/sweep/maxlogit__robust
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=RO21_coco | method=rba | T=1.0 | mode=robust | sw=False
# AUPRC: 0.4767
# FPR@95TPR: 75.5230
# Images used: 30
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/logits/RO21_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/logits/RO21_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/logits/RO21_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/logits/RO21_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f
# [T=0.5] AUPRC=0.4792 | FPR95=75.7136 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/sweep/rba__robust/T0.5__metrics.json
# [T=0.75] AUPRC=0.4792 | FPR95=75.7378 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/sweep/rba__robust/T0.75__metrics.json
# [T=1.0] AUPRC=0.4791 | FPR95=75.7650 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/sweep/rba__robust/T1.0__metrics.json
# [T=1.1] AUPRC=0.4790 | FPR95=75.7906 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/sweep/rba__robust/T1.1__metrics.json
# [T=1.25] AUPRC=0.4790 | FPR95=75.8108 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/sweep/rba__robust/T1.25__metrics.json
# [T=1.5] AUPRC=0.4792 | FPR95=75.8098 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/sweep/rba__robust/T1.5__metrics.json
# [T=2.0] AUPRC=0.4801 | FPR95=75.7037 | saved /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/sweep/rba__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/RO21_coco/EoMT/2026-05-08_15-33-54__rba__T1.0__robust__f05c798f/sweep/rba__robust

# %% [markdown]
# ## 6. Evaluation — LostAndFound

# %%
DATA = 'LAF'
INP  = f'{DATA_DIR}/LostAndFound/images/*.*'

for method in ['msp', 'maxentropy', 'maxlogit', 'rba']:
    eomt_coco(DATA, INP, method)
# Out:
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=LAF_coco | method=msp | T=1.0 | mode=robust | sw=False
# AUPRC: 0.7385
# FPR@95TPR: 74.6305
# Images used: 99
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/logits/LAF_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/logits/LAF_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/logits/LAF_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/logits/LAF_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342
# [T=0.5] AUPRC=0.1966 | FPR95=98.9766 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/sweep/msp__robust/T0.5__metrics.json
# [T=0.75] AUPRC=0.1915 | FPR95=98.6024 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/sweep/msp__robust/T0.75__metrics.json
# [T=1.0] AUPRC=0.1941 | FPR95=98.1033 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/sweep/msp__robust/T1.0__metrics.json
# [T=1.1] AUPRC=0.1968 | FPR95=97.2843 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/sweep/msp__robust/T1.1__metrics.json
# [T=1.25] AUPRC=0.2025 | FPR95=96.4310 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/sweep/msp__robust/T1.25__metrics.json
# [T=1.5] AUPRC=0.2164 | FPR95=95.4756 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/sweep/msp__robust/T1.5__metrics.json
# [T=2.0] AUPRC=0.2551 | FPR95=94.3383 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/sweep/msp__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-34-37__msp__T1.0__robust__c7f6b342/sweep/msp__robust
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=LAF_coco | method=maxentropy | T=1.0 | mode=robust | sw=False
# AUPRC: 3.5580
# FPR@95TPR: 76.1316
# Images used: 99
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/logits/LAF_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/logits/LAF_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/logits/LAF_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/logits/LAF_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075
# [T=0.5] AUPRC=0.1980 | FPR95=98.9479 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/sweep/maxentropy__robust/T0.5__metrics.json
# [T=0.75] AUPRC=0.2033 | FPR95=98.2783 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/sweep/maxentropy__robust/T0.75__metrics.json
# [T=1.0] AUPRC=0.2323 | FPR95=96.4939 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/sweep/maxentropy__robust/T1.0__metrics.json
# [T=1.1] AUPRC=0.2492 | FPR95=95.8939 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/sweep/maxentropy__robust/T1.1__metrics.json
# [T=1.25] AUPRC=0.2763 | FPR95=93.9393 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/sweep/maxentropy__robust/T1.25__metrics.json
# [T=1.5] AUPRC=0.3287 | FPR95=90.7868 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/sweep/maxentropy__robust/T1.5__metrics.json
# [T=2.0] AUPRC=0.4298 | FPR95=83.7818 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/sweep/maxentropy__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-40-17__maxentropy__T1.0__robust__90911075/sweep/maxentropy__robust
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=LAF_coco | method=maxlogit | T=1.0 | mode=robust | sw=False
# AUPRC: 0.1923
# FPR@95TPR: 89.1198
# Images used: 99
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/logits/LAF_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/logits/LAF_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/logits/LAF_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/logits/LAF_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628
# [T=0.5] AUPRC=0.1807 | FPR95=94.2931 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/sweep/maxlogit__robust/T0.5__metrics.json
# [T=0.75] AUPRC=0.1807 | FPR95=94.2931 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/sweep/maxlogit__robust/T0.75__metrics.json
# [T=1.0] AUPRC=0.1807 | FPR95=94.2931 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/sweep/maxlogit__robust/T1.0__metrics.json
# [T=1.1] AUPRC=0.1807 | FPR95=94.2931 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/sweep/maxlogit__robust/T1.1__metrics.json
# [T=1.25] AUPRC=0.1807 | FPR95=94.2931 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/sweep/maxlogit__robust/T1.25__metrics.json
# [T=1.5] AUPRC=0.1807 | FPR95=94.2931 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/sweep/maxlogit__robust/T1.5__metrics.json
# [T=2.0] AUPRC=0.1807 | FPR95=94.2931 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/sweep/maxlogit__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-42-46__maxlogit__T1.0__robust__9e5d0628/sweep/maxlogit__robust
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=LAF_coco | method=rba | T=1.0 | mode=robust | sw=False
# AUPRC: 0.2037
# FPR@95TPR: 87.8138
# Images used: 99
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/logits/LAF_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/logits/LAF_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/logits/LAF_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/logits/LAF_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6
# [T=0.5] AUPRC=0.1961 | FPR95=90.0806 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/sweep/rba__robust/T0.5__metrics.json
# [T=0.75] AUPRC=0.1955 | FPR95=90.2174 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/sweep/rba__robust/T0.75__metrics.json
# [T=1.0] AUPRC=0.1952 | FPR95=89.9279 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/sweep/rba__robust/T1.0__metrics.json
# [T=1.1] AUPRC=0.1952 | FPR95=89.6696 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/sweep/rba__robust/T1.1__metrics.json
# [T=1.25] AUPRC=0.1955 | FPR95=89.3427 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/sweep/rba__robust/T1.25__metrics.json
# [T=1.5] AUPRC=0.1964 | FPR95=88.3795 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/sweep/rba__robust/T1.5__metrics.json
# [T=2.0] AUPRC=0.1988 | FPR95=86.3706 | saved /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/sweep/rba__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/LAF_coco/EoMT/2026-05-08_15-45-11__rba__T1.0__robust__2af5b5b6/sweep/rba__robust

# %% [markdown]
# ## 7. Evaluation — Fishyscapes Static

# %%
DATA = 'fs_static'
INP  = f'{DATA_DIR}/fs_static/images/*.*'

for method in ['msp', 'maxentropy', 'maxlogit', 'rba']:
    eomt_coco(DATA, INP, method)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=fs_static_coco | method=msp | T=1.0 | mode=robust | sw=False
# AUPRC: 4.3331
# FPR@95TPR: 81.9514
# Images used: 20
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/logits/fs_static_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/logits/fs_static_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/logits/fs_static_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/logits/fs_static_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709
# [T=0.5] AUPRC=2.0299 | FPR95=97.9073 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/sweep/msp__robust/T0.5__metrics.json
# [T=0.75] AUPRC=2.1167 | FPR95=96.7341 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/sweep/msp__robust/T0.75__metrics.json
# [T=1.0] AUPRC=2.2360 | FPR95=95.3730 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/sweep/msp__robust/T1.0__metrics.json
# [T=1.1] AUPRC=2.3160 | FPR95=94.6058 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/sweep/msp__robust/T1.1__metrics.json
# [T=1.25] AUPRC=2.4378 | FPR95=93.7625 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/sweep/msp__robust/T1.25__metrics.json
# [T=1.5] AUPRC=2.6520 | FPR95=93.0035 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/sweep/msp__robust/T1.5__metrics.json
# [T=2.0] AUPRC=3.1620 | FPR95=92.1915 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/sweep/msp__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-47-27__msp__T1.0__robust__616b2709/sweep/msp__robust
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=fs_static_coco | method=maxentropy | T=1.0 | mode=robust | sw=False
# AUPRC: 5.0409
# FPR@95TPR: 83.4558
# Images used: 20
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/logits/fs_static_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/logits/fs_static_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/logits/fs_static_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/logits/fs_static_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3
# [T=0.5] AUPRC=2.4086 | FPR95=97.8063 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/sweep/maxentropy__robust/T0.5__metrics.json
# [T=0.75] AUPRC=2.5484 | FPR95=96.5978 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/sweep/maxentropy__robust/T0.75__metrics.json
# [T=1.0] AUPRC=2.8945 | FPR95=94.8975 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/sweep/maxentropy__robust/T1.0__metrics.json
# [T=1.1] AUPRC=3.1439 | FPR95=93.8348 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/sweep/maxentropy__robust/T1.1__metrics.json
# [T=1.25] AUPRC=3.3376 | FPR95=92.9734 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/sweep/maxentropy__robust/T1.25__metrics.json
# [T=1.5] AUPRC=3.5012 | FPR95=89.2854 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/sweep/maxentropy__robust/T1.5__metrics.json
# [T=2.0] AUPRC=3.7591 | FPR95=86.3116 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/sweep/maxentropy__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-08__maxentropy__T1.0__robust__51d3e7a3/sweep/maxentropy__robust
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=fs_static_coco | method=maxlogit | T=1.0 | mode=robust | sw=False
# AUPRC: 1.7371
# FPR@95TPR: 88.1283
# Images used: 20
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/logits/fs_static_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/logits/fs_static_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/logits/fs_static_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/logits/fs_static_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611
# [T=0.5] AUPRC=1.6887 | FPR95=93.2554 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/sweep/maxlogit__robust/T0.5__metrics.json
# [T=0.75] AUPRC=1.6887 | FPR95=93.2554 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/sweep/maxlogit__robust/T0.75__metrics.json
# [T=1.0] AUPRC=1.6887 | FPR95=93.2554 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/sweep/maxlogit__robust/T1.0__metrics.json
# [T=1.1] AUPRC=1.6887 | FPR95=93.2554 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/sweep/maxlogit__robust/T1.1__metrics.json
# [T=1.25] AUPRC=1.6887 | FPR95=93.2554 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/sweep/maxlogit__robust/T1.25__metrics.json
# [T=1.5] AUPRC=1.6887 | FPR95=93.2554 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/sweep/maxlogit__robust/T1.5__metrics.json
# [T=2.0] AUPRC=1.6887 | FPR95=93.2554 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/sweep/maxlogit__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-49-52__maxlogit__T1.0__robust__3772f611/sweep/maxlogit__robust
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=fs_static_coco | method=rba | T=1.0 | mode=robust | sw=False
# AUPRC: 1.7597
# FPR@95TPR: 80.0722
# Images used: 20
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/logits/fs_static_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/logits/fs_static_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/logits/fs_static_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/logits/fs_static_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38
# [T=0.5] AUPRC=1.6873 | FPR95=84.1970 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/sweep/rba__robust/T0.5__metrics.json
# [T=0.75] AUPRC=1.6879 | FPR95=85.5462 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/sweep/rba__robust/T0.75__metrics.json
# [T=1.0] AUPRC=1.6907 | FPR95=86.5743 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/sweep/rba__robust/T1.0__metrics.json
# [T=1.1] AUPRC=1.6924 | FPR95=86.9723 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/sweep/rba__robust/T1.1__metrics.json
# [T=1.25] AUPRC=1.6962 | FPR95=87.6681 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/sweep/rba__robust/T1.25__metrics.json
# [T=1.5] AUPRC=1.7034 | FPR95=88.0628 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/sweep/rba__robust/T1.5__metrics.json
# [T=2.0] AUPRC=1.7208 | FPR95=87.4822 | saved /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/sweep/rba__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/fs_static_coco/EoMT/2026-05-08_15-50-35__rba__T1.0__robust__46ee2f38/sweep/rba__robust

# %% [markdown]
# ## 8. Evaluation — Road Anomaly

# %%
DATA = 'RA'
INP  = f'{DATA_DIR}/RoadAnomaly/images/*.*'

for method in ['msp', 'maxentropy', 'maxlogit', 'rba']:
    eomt_coco(DATA, INP, method)
# Out:
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=RA_coco | method=msp | T=1.0 | mode=robust | sw=False
# AUPRC: 14.4507
# FPR@95TPR: 97.5774
# Images used: 60
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/logits/RA_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/logits/RA_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/logits/RA_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/logits/RA_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485
# [T=0.5] AUPRC=8.8916 | FPR95=94.2002 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/sweep/msp__robust/T0.5__metrics.json
# [T=0.75] AUPRC=8.6878 | FPR95=94.2321 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/sweep/msp__robust/T0.75__metrics.json
# [T=1.0] AUPRC=8.6335 | FPR95=93.4411 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/sweep/msp__robust/T1.0__metrics.json
# [T=1.1] AUPRC=8.6734 | FPR95=93.2169 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/sweep/msp__robust/T1.1__metrics.json
# [T=1.25] AUPRC=8.8204 | FPR95=93.3911 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/sweep/msp__robust/T1.25__metrics.json
# [T=1.5] AUPRC=9.2541 | FPR95=95.1603 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/sweep/msp__robust/T1.5__metrics.json
# [T=2.0] AUPRC=10.5280 | FPR95=96.7074 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/sweep/msp__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-51-16__msp__T1.0__robust__245ca485/sweep/msp__robust
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=RA_coco | method=maxentropy | T=1.0 | mode=robust | sw=False
# AUPRC: 26.5370
# FPR@95TPR: 95.3862
# Images used: 60
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/logits/RA_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/logits/RA_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/logits/RA_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/logits/RA_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2
# [T=0.5] AUPRC=8.9820 | FPR95=94.1554 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/sweep/maxentropy__robust/T0.5__metrics.json
# [T=0.75] AUPRC=8.7832 | FPR95=93.6691 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/sweep/maxentropy__robust/T0.75__metrics.json
# [T=1.0] AUPRC=9.5961 | FPR95=92.3606 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/sweep/maxentropy__robust/T1.0__metrics.json
# [T=1.1] AUPRC=10.2542 | FPR95=92.5526 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/sweep/maxentropy__robust/T1.1__metrics.json
# [T=1.25] AUPRC=11.5243 | FPR95=93.9623 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/sweep/maxentropy__robust/T1.25__metrics.json
# [T=1.5] AUPRC=13.5535 | FPR95=94.3230 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/sweep/maxentropy__robust/T1.5__metrics.json
# [T=2.0] AUPRC=17.9379 | FPR95=94.2378 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/sweep/maxentropy__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-54-39__maxentropy__T1.0__robust__0f3a39b2/sweep/maxentropy__robust
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=RA_coco | method=maxlogit | T=1.0 | mode=robust | sw=False
# AUPRC: 8.9154
# FPR@95TPR: 93.1440
# Images used: 60
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/logits/RA_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/logits/RA_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/logits/RA_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/logits/RA_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4
# [T=0.5] AUPRC=8.5772 | FPR95=95.5119 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/sweep/maxlogit__robust/T0.5__metrics.json
# [T=0.75] AUPRC=8.5772 | FPR95=95.5119 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/sweep/maxlogit__robust/T0.75__metrics.json
# [T=1.0] AUPRC=8.5772 | FPR95=95.5119 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/sweep/maxlogit__robust/T1.0__metrics.json
# [T=1.1] AUPRC=8.5772 | FPR95=95.5119 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/sweep/maxlogit__robust/T1.1__metrics.json
# [T=1.25] AUPRC=8.5772 | FPR95=95.5119 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/sweep/maxlogit__robust/T1.25__metrics.json
# [T=1.5] AUPRC=8.5772 | FPR95=95.5119 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/sweep/maxlogit__robust/T1.5__metrics.json
# [T=2.0] AUPRC=8.5772 | FPR95=95.5119 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/sweep/maxlogit__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-56-19__maxlogit__T1.0__robust__430e69f4/sweep/maxlogit__robust
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [device] cuda
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc
# [EoMT][robust] Loaded fuzzy weights from: /content/drive/MyDrive/anom_project/ckpts/eomt/eomt_coco.bin | missing=1 unexpected=0
# =====================================
# EoMT | dataset=RA_coco | method=rba | T=1.0 | mode=robust | sw=False
# AUPRC: 9.0595
# FPR@95TPR: 89.0936
# Images used: 60
# Crop: 640x640 | logits ref: 160x160
# =====================================
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/results/metrics.json
# [SAVED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/results/metrics.csv
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/logits/RA_coco__mask_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/logits/RA_coco__class_logits_f16.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/logits/RA_coco__gt.npy
# [CACHED] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/logits/RA_coco__names.json
# [ARTIFACTS] /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc
# [T=0.5] AUPRC=8.9182 | FPR95=81.8274 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/sweep/rba__robust/T0.5__metrics.json
# [T=0.75] AUPRC=8.8791 | FPR95=84.2913 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/sweep/rba__robust/T0.75__metrics.json
# [T=1.0] AUPRC=8.8581 | FPR95=85.8290 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/sweep/rba__robust/T1.0__metrics.json
# [T=1.1] AUPRC=8.8568 | FPR95=86.3399 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/sweep/rba__robust/T1.1__metrics.json
# [T=1.25] AUPRC=8.8675 | FPR95=87.1755 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/sweep/rba__robust/T1.25__metrics.json
# [T=1.5] AUPRC=8.9079 | FPR95=86.9483 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/sweep/rba__robust/T1.5__metrics.json
# [T=2.0] AUPRC=9.0236 | FPR95=86.6066 | saved /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/sweep/rba__robust/T2.0__metrics.json
# [DONE] Run used: /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc
# [DONE] Sweep results in: /content/drive/MyDrive/anom_project/artifacts/RA_coco/EoMT/2026-05-08_15-57-57__rba__T1.0__robust__25a8f6bc/sweep/rba__robust

# %% [markdown]
# ## 9. Collect results

# %%
run([
    'python3', '-m', 'src.scripts.collect_results',
    '--artifacts-dir', ART,
    '--export-json',   f'{RESULTS_DIR}/all_results.json',
])
# Out:
# ======================================================================
#   RA21
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   ERFNet   msp               29.10    62.55      10
#   ERFNet   maxentropy        30.97    62.66      10
#   ERFNet   maxlogit          38.32    59.34      10
#   EoMT     msp               37.52    67.56      10
#   EoMT     maxentropy        24.56    66.95      10
#   EoMT     maxlogit          68.22    26.63      10
#   EoMT     rba               58.95    57.86      10
#
# ======================================================================
#   RO21
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   ERFNet   msp                2.71    65.22      30
#   ERFNet   maxentropy         3.04    65.91      30
#   ERFNet   maxlogit           4.63    48.44      30
#   EoMT     msp               56.56    99.55      30
#   EoMT     maxentropy        50.35    99.70      30
#   EoMT     maxlogit          35.05   100.00      30
#   EoMT     rba               91.52     5.40      30
#
# ======================================================================
#   LAF
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   ERFNet   msp                1.75    50.60      99
#   ERFNet   maxentropy         2.58    50.16      99
#   ERFNet   maxlogit           3.30    45.49      99
#   EoMT     msp                0.74    57.28      99
#   EoMT     maxentropy         0.72    56.69      99
#   EoMT     maxlogit          22.41    43.81      99
#   EoMT     rba               19.51    69.20      99
#
# ======================================================================
#   fs_static
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   ERFNet   msp                7.47    41.84      20
#   ERFNet   maxentropy         8.84    41.55      20
#   ERFNet   maxlogit           9.50    40.30      20
#   EoMT     msp                3.16    58.24      20
#   EoMT     maxentropy         2.66    57.32      20
#   EoMT     maxlogit          58.16    53.18      20
#   EoMT     rba               51.24    97.95      20
#
# ======================================================================
#   RA
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   ERFNet   msp               12.42    82.58      60
#   ERFNet   maxentropy        12.67    82.75      60
#   ERFNet   maxlogit          15.58    73.25      60
#   EoMT     msp               22.84    74.37      60
#   EoMT     maxentropy        22.86    74.50      60
#   EoMT     maxlogit          71.49    29.47      60
#   EoMT     rba               73.08    29.96      60
#
# ======================================================================
#   RA21_1024
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   EoMT     msp               87.36    56.08      10
#   EoMT     maxentropy        14.32   100.00      10
#   EoMT     maxlogit          82.76    19.78      10
#   EoMT     rba               56.77    25.48      10
#
# ======================================================================
#   RO21_1024
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   EoMT     msp               64.67    99.99      30
#   EoMT     maxentropy        15.22   100.00      30
#   EoMT     maxlogit          43.14    98.49      30
#   EoMT     rba                8.31    95.81      30
#
# ======================================================================
#   LAF_1024
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   EoMT     msp                3.33    97.92      99
#   EoMT     maxentropy         0.40    99.59      99
#   EoMT     maxlogit           5.13    47.38      99
#   EoMT     rba                3.66    46.32      99
#
# ======================================================================
#   fs_static_1024
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   EoMT     msp               14.67    87.37      20
#   EoMT     maxentropy         4.24    99.76      20
#   EoMT     maxlogit          20.87    39.34      20
#   EoMT     rba               12.76    39.69      20
#
# ======================================================================
#   RA_1024
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   EoMT     msp               57.99    64.74      60
#   EoMT     maxentropy         7.43    99.91      60
#   EoMT     maxlogit          44.92    47.95      60
#   EoMT     rba               32.36    48.83      60
#
# [SAVED] /content/drive/MyDrive/anom_project/results/all_results.json

# %% [markdown]
# ## 10. Collect sweeps

# %%
import json
from pathlib import Path

sweep_results = {}

for sweep_json in sorted(Path(ART).glob('*_coco/*/*/sweep/*/*__metrics.json')):
    parts       = sweep_json.parts
    dataset     = parts[-6]
    model       = parts[-5]
    method_mode = parts[-2]
    t_name      = parts[-1]
    T_val       = t_name.replace('__metrics.json', '').replace('T', '')
    method      = method_mode.split('__')[0]

    with open(sweep_json) as f:
        m = json.load(f)

    key = f'{dataset}/{model}/{method}'
    if key not in sweep_results:
        sweep_results[key] = []
    sweep_results[key].append({
        'T':     float(T_val),
        'auprc': m.get('auprc_pct', m.get('auprc', 0) * 100),
        'fpr95': m.get('fpr95_pct', m.get('fpr95', 0) * 100),
    })

# Deduplicate
for key in sweep_results:
    seen = {}
    for entry in sweep_results[key]:
        t = entry['T']
        if t not in seen or entry['auprc'] > seen[t]['auprc']:
            seen[t] = entry
    sweep_results[key] = sorted(seen.values(), key=lambda x: x['T'])

out = f'{RESULTS_DIR}/all_sweeps_coco.json'
with open(out, 'w') as f:
    json.dump(sweep_results, f, indent=2)

print(f'[SAVED] {out}')
print(f'Keys found: {len(sweep_results)}')
for k in sorted(sweep_results.keys()):
    best = max(sweep_results[k], key=lambda x: x['auprc'])
    print(f'  {k}: best AuPRC={best["auprc"]:.2f} @ T={best["T"]}')
# Out:
# [SAVED] /content/drive/MyDrive/anom_project/results/all_sweeps_coco.json
# Keys found: 20
#   LAF_coco/EoMT/maxentropy: best AuPRC=0.43 @ T=2.0
#   LAF_coco/EoMT/maxlogit: best AuPRC=0.18 @ T=0.5
#   LAF_coco/EoMT/msp: best AuPRC=0.26 @ T=2.0
#   LAF_coco/EoMT/rba: best AuPRC=0.20 @ T=2.0
#   RA21_coco/EoMT/maxentropy: best AuPRC=35.81 @ T=2.0
#   RA21_coco/EoMT/maxlogit: best AuPRC=16.17 @ T=0.5
#   RA21_coco/EoMT/msp: best AuPRC=22.17 @ T=2.0
#   RA21_coco/EoMT/rba: best AuPRC=15.85 @ T=2.0
#   RA_coco/EoMT/maxentropy: best AuPRC=17.94 @ T=2.0
#   RA_coco/EoMT/maxlogit: best AuPRC=8.58 @ T=0.5
#   RA_coco/EoMT/msp: best AuPRC=10.53 @ T=2.0
#   RA_coco/EoMT/rba: best AuPRC=9.02 @ T=2.0
#   RO21_coco/EoMT/maxentropy: best AuPRC=1.07 @ T=0.5
#   RO21_coco/EoMT/maxlogit: best AuPRC=0.38 @ T=0.5
#   RO21_coco/EoMT/msp: best AuPRC=0.89 @ T=0.5
#   RO21_coco/EoMT/rba: best AuPRC=0.48 @ T=2.0
#   fs_static_coco/EoMT/maxentropy: best AuPRC=3.76 @ T=2.0
#   fs_static_coco/EoMT/maxlogit: best AuPRC=1.69 @ T=0.5
#   fs_static_coco/EoMT/msp: best AuPRC=3.16 @ T=2.0
#   fs_static_coco/EoMT/rba: best AuPRC=1.72 @ T=2.0
