# %%
import os
import subprocess
import sys
from google.colab import userdata, drive

# ── Secrets (set in Colab:  Secrets panel) ────────────────
GITHUB_USER  = userdata.get("GITHUB_USERNAME")
GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")
GITHUB_REPO  = userdata.get("GITHUB_REPO")
USER_EMAIL   = userdata.get("USER_EMAIL")
REPO_URL     = f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{GITHUB_REPO}.git"

# ── Google Drive ─────────────────────────────────────────────
drive.mount("/content/drive")

# ── Clone or pull repository ─────────────────────────────────
# %cd /content
if os.path.exists(GITHUB_REPO):
    # %cd /content/{GITHUB_REPO}
    # !git pull {REPO_URL} main --rebase
else:
    # !git clone {REPO_URL}
    # %cd /content/{GITHUB_REPO}

# !git config user.email "{USER_EMAIL}"
# !git config user.name "{GITHUB_USER}"
# !ls
print("✓ Repository ready")
# Out:
# Mounted at /content/drive
# /content
# Cloning into 'Foundamental_Ai_private'...
# remote: Enumerating objects: 515, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 515 (delta 78), reused 125 (delta 43), pack-reused 351 (from 1)
# Receiving objects: 100% (515/515), 27.02 MiB | 30.38 MiB/s, done.
# Resolving deltas: 100% (215/215), done.
# /content/Foundamental_Ai_private
# artifacts  eval       README.md       src
# eomt	   notebooks  README_PROJ.md  trained_models
# ✓ Repository ready

# %%
# !python src/scripts/collect_results.py \
    --artifacts-dir /content/drive/MyDrive/anom_project/artifacts \
    --export-json   /content/drive/MyDrive/anom_project/all_results.json
# Out:
# ======================================================================
#   RA21
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   ERFNet   msp               29.10    62.55      10
#   ERFNet   maxentropy        30.97    62.66      10
#   ERFNet   maxlogit          38.32    59.34      10
#   EoMT     msp               37.52    67.56      10
#   EoMT     maxentropy        24.56    66.95      10
#   EoMT     maxlogit          68.22    26.63      10
#   EoMT     rba               58.95    57.86      10
#
# ======================================================================
#   RO21
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   ERFNet   msp                2.71    65.22      30
#   ERFNet   maxentropy         3.04    65.91      30
#   ERFNet   maxlogit           4.63    48.44      30
#   EoMT     msp               56.56    99.55      30
#   EoMT     maxentropy        50.35    99.70      30
#   EoMT     maxlogit          35.05   100.00      30
#   EoMT     rba               91.52     5.40      30
#
# ======================================================================
#   LAF
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   ERFNet   msp                1.75    50.60      99
#   ERFNet   maxentropy         2.58    50.16      99
#   ERFNet   maxlogit           3.30    45.49      99
#   EoMT     msp                0.74    57.28      99
#   EoMT     maxentropy         0.72    56.69      99
#   EoMT     maxlogit          22.41    43.81      99
#   EoMT     rba               19.51    69.20      99
#
# ======================================================================
#   fs_static
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   ERFNet   msp                7.47    41.84      20
#   ERFNet   maxentropy         8.84    41.55      20
#   ERFNet   maxlogit           9.50    40.30      20
#   EoMT     msp                3.16    58.24      20
#   EoMT     maxentropy         2.66    57.32      20
#   EoMT     maxlogit          58.16    53.18      20
#   EoMT     rba               51.24    97.95      20
#
# ======================================================================
#   RA
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   ERFNet   msp               12.42    82.58      60
#   ERFNet   maxentropy        12.67    82.75      60
#   ERFNet   maxlogit          15.58    73.25      60
#   EoMT     msp               22.84    74.37      60
#   EoMT     maxentropy        22.86    74.50      60
#   EoMT     maxlogit          71.49    29.47      60
#   EoMT     rba               73.08    29.96      60
#
# ======================================================================
#   RA21_1024
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   EoMT     msp               87.36    56.08      10
#   EoMT     maxentropy        14.32   100.00      10
#   EoMT     maxlogit          82.76    19.78      10
#   EoMT     rba               56.77    25.48      10
#
# ======================================================================
#   RO21_1024
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   EoMT     msp               64.67    99.99      30
#   EoMT     maxentropy        15.22   100.00      30
#   EoMT     maxlogit          43.14    98.49      30
#   EoMT     rba                8.31    95.81      30
#
# ======================================================================
#   LAF_1024
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   EoMT     msp                3.33    97.92      99
#   EoMT     maxentropy         0.40    99.59      99
#   EoMT     maxlogit           5.13    47.38      99
#   EoMT     rba                3.66    46.32      99
#
# ======================================================================
#   fs_static_1024
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   EoMT     msp               14.67    87.37      20
#   EoMT     maxentropy         4.24    99.76      20
#   EoMT     maxlogit          20.87    39.34      20
#   EoMT     rba               12.76    39.69      20
#
# ======================================================================
#   RA_1024
# ======================================================================
#   Model    Method            AuPRC    FPR95  Images
#   --------------------------------------------------
#   EoMT     msp               57.99    64.74      60
#   EoMT     maxentropy         7.43    99.91      60
#   EoMT     maxlogit          44.92    47.95      60
#   EoMT     rba               32.36    48.83      60
#
# [SAVED] /content/drive/MyDrive/anom_project/all_results.json

# %%
import json
from pathlib import Path

ART = "/content/drive/MyDrive/anom_project/artifacts"

print("All ERFNet MSP runs on RA21:")
for p in sorted(Path(ART).glob("RA21/ERFNet/*/results/metrics.json")):
    with open(p) as f:
        m = json.load(f)
    if m.get("method") == "msp":
        print(f"  {m.get('timestamp_utc')} | AuPRC={m.get('auprc_pct'):.4f} | run={p.parts[-3]}")
# Out:
# All ERFNet MSP runs on RA21:
#   None | AuPRC=15.2131 | run=2026-03-01_11-29-18__msp__T1.0__robust__d03543bc
#   None | AuPRC=15.0489 | run=2026-03-01_11-37-25__msp__T1.0__prof-exact__948e9eda
#   None | AuPRC=14.5576 | run=2026-03-01_11-49-30__msp__T1.0__prof-exact__948e9eda
#   None | AuPRC=14.8159 | run=2026-03-01_11-51-50__msp__T1.0__robust__d03543bc
#   None | AuPRC=29.0951 | run=2026-03-01_12-28-22__msp__T1.0__robust__559e7ee5
#   None | AuPRC=29.0951 | run=2026-03-01_12-28-47__msp__T1.0__prof-exact__464753d5
#   None | AuPRC=29.0951 | run=2026-03-01_12-29-31__msp__T1.0__prof-exact__4891cb02
#   None | AuPRC=29.0951 | run=2026-03-01_14-28-32__msp__T1.0__robust__d17d9a42
#   None | AuPRC=29.0951 | run=2026-03-01_14-52-30__msp__T1.0__robust__d17d9a42
#   None | AuPRC=29.0951 | run=2026-03-01_16-53-13__msp__T1.0__robust__64c294c4
#   None | AuPRC=29.0951 | run=2026-03-31_11-03-26__msp__T1.0__robust__8e036a29
